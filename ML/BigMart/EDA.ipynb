# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
path=os.getcwd()+'/Big_mart.csv'
df=pd.read_csv(path)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df['Outlet_Size']=df['Outlet_Size'].fillna((df['Outlet_Size'].mode()[0]))
df=df.fillna(df.mean())

# %%
df['Item_Visibility'].replace(0.000000,np.nan,inplace=True)
df['Item_Visibility']=df['Item_Visibility'].fillna(df['Item_Visibility'].mean())

# %%
df['Item_Fat_Content'].replace(['LF','low fat'],'Low Fat',inplace=True)
df['Item_Fat_Content'].replace('reg','Regular',inplace=True)

# %%
sns.distplot(df['Item_Weight'])

# %%
sns.distplot(df['Item_Visibility'])

# %%
sns.distplot(df['Item_MRP'])

# %%
sns.distplot(df['Item_Outlet_Sales'])

# %%
sns.countplot(x='Outlet_Location_Type',data=df)

# %%
sns.countplot(x='Outlet_Establishment_Year',data=df)

# %%
#Graph below shows the count of each type of product

# %%
plt.figure(figsize=(22,8))
sns.countplot(x='Item_Type',data=df)

# %%
sns.heatmap(df.corr(),annot=True)

# %%
#Graph above shows that Item MRP and Item Outlet Sales have highest Correlation

# %%
#Graph Below shows the variation of Item Sales with Item MRP

# %%
sns.jointplot(x='Item_MRP',y='Item_Outlet_Sales',data=df,color='g',alpha=0.5)

# %%
# 1. Items between MRP 200-250 have the highest sales

# %%
sns.jointplot(x='Item_MRP',y='Item_Outlet_Sales',data=df,kind='kde',color='b')

# %%
plt.scatter(df['Item_Visibility'], df['Item_Outlet_Sales'])
plt.xlabel('Item Visibility')
plt.ylabel('Item Outlet Sales')
# Out:
# Text(0,0.5,'Item Outlet Sales')

# %%
sns.lmplot(x='Item_MRP',y='Item_Outlet_Sales',data=df,hue='Item_Type',fit_reg=False)

# %%
#Graph shows which of type of item lies in what MRP range and what is their outlet sales

# %%
sns.boxplot(y='Item_MRP',data=df)

# %%
# Graph Below shows the sales of each Outlet

# %%
plt.figure(figsize=(22,8))
sns.boxplot(x='Outlet_Identifier',y='Item_Outlet_Sales',data=df)

# %%
# Below 2 graph shows the relation between Item Visibilty,their types and their Outlet sales

# %%
plt.figure(figsize=(25,8))
sns.boxplot(x='Item_Type',y='Item_Visibility',data=df)

# %%
plt.figure(figsize=(25,8))
sns.boxplot(x='Item_Type',y='Item_Outlet_Sales',data=df)
